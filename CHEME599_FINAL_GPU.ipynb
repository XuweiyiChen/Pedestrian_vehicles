# %% [markdown]
# # YOLOv3 Implementation for Pedestrian Detection
#
# Written by Xuweiyi Chen & Jenny Rong

# %% [markdown]
# ### Load Data
#
# I have tried many different approaches in order to load the data into iCloud. Due to the fact the dataset I need to apply in order to make my model converge is very huge, there are many times I cannot fully load the data and labels perfectly. This is my final approches which brings the dataset into cloud and people can utilized the same approaches in order to make their customized change.
#
# This approaches is based on kaggle. For which this Kaggle approaches, people should have their own kaggle account and initilize their own API such as a *kaggle.json* file.

# %% [markdown]
# #### First Step: Install Kaggle on Colab

# %%
# !pip install -q kaggle

# %% [markdown]
# #### Second Step: Upload *kaggle.json* to the Colab.

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5bc92af0-7c81-4cf3-9299-acb34cd4fe8a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5bc92af0-7c81-4cf3-9299-acb34cd4fe8a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"xuweiyichen","key":"dc965c3dcfa276c594bde9a7b2c43dba"}'}

# %% [markdown]
# #### Third Step: Make a directory and copy the identification file into the directory

# %%
mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle

# %% [markdown]
# #### Fourth Step: Connect kaggle using your *kaggle.json* file

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# #### Fifth Step: Make sure you can access kaggle right now

# %%
# !kaggle datasets list
# Out:
# ...
# ref                                                         title                                              size  lastUpdated          downloadCount
# ----------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------
# gpreda/reddit-vaccine-myths                                 Reddit Vaccine Myths                              229KB  2021-06-01 11:18:46           6801
# crowww/a-large-scale-fish-dataset                           A Large Scale Fish Dataset                          3GB  2021-04-28 17:03:01           4042
# imsparsh/musicnet-dataset                                   MusicNet Dataset                                   22GB  2021-02-18 14:12:19           1358
# dhruvildave/wikibooks-dataset                               Wikibooks Dataset                                   1GB  2021-02-18 10:08:27           2126
# ...

# %% [markdown]
# #### Sixth Step: Download the kaggle dataset you want to use and unzip it

# %%
# !kaggle datasets download -d aladdinpersson/pascal-voc-dataset-used-in-yolov3-video
# Out:
# ...
# 100% 4.29G/4.31G [00:50<00:00, 93.6MB/s]
# 100% 4.31G/4.31G [00:50<00:00, 92.0MB/s]

# %%
# !unzip /content/pascal-voc-dataset-used-in-yolov3-video.zip
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: PASCAL_VOC/labels/2009_004289.txt
#   inflating: PASCAL_VOC/labels/2009_004290.txt
#   inflating: PASCAL_VOC/labels/2009_004291.txt
#   inflating: PASCAL_VOC/labels/2009_004295.txt
#   inflating: PASCAL_VOC/labels/2009_004298.txt
#   inflating: PASCAL_VOC/labels/2009_004300.txt
#   inflating: PASCAL_VOC/labels/2009_004301.txt
#   inflating: PASCAL_VOC/labels/2009_004303.txt
#   inflating: PASCAL_VOC/labels/2009_004307.txt
#   inflating: PASCAL_VOC/labels/2009_004308.txt
#   inflating: PASCAL_VOC/labels/2009_004309.txt
#   inflating: PASCAL_VOC/labels/2009_004312.txt
#   inflating: PASCAL_VOC/labels/2009_004315.txt
#   inflating: PASCAL_VOC/labels/2009_004316.txt
#   inflating: PASCAL_VOC/labels/2009_004317.txt
#   inflating: PASCAL_VOC/labels/2009_004319.txt
#   inflating: PASCAL_VOC/labels/2009_004322.txt
#   inflating: PASCAL_VOC/labels/2009_004323.txt
#   inflating: PASCAL_VOC/labels/2009_004324.txt
# ...

# %% [markdown]
# #### Download the required code and create the desired file structures

# %%
# !git clone https://github.com/XuweiyiChen/YOLOv3.git
# Out:
# Cloning into 'YOLOv3'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 11 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (11/11), done.

# %%
# !mv PASCAL_VOC YOLOv3

# %%
# !ls YOLOv3
# Out:
# config.py   loss.py   PASCAL_VOC  train.py
# dataset.py  model.py  README.md   utils.py

# %%
# !ls YOLOv3/PASCAL_VOC
# Out:
# 100examples.csv  2examples.csv	images	test.csv
# 1examples.csv	 8examples.csv	labels	train.csv

# %% [markdown]
# #### Update one package in order to run the file

# %%
# !pip install --upgrade --force-reinstall --no-deps albumentations
# Out:
# ...
#      |████████████████████████████████| 102kB 5.1MB/s
# ...
#   Found existing installation: albumentations 0.1.12
#     Uninstalling albumentations-0.1.12:
#       Successfully uninstalled albumentations-0.1.12
# ...

# %%
# !cd YOLOv3

# %%
# !ls YOLOv3
# Out:
# config.py   loss.py   PASCAL_VOC  train.py
# dataset.py  model.py  README.md   utils.py

# %% [markdown]
# Start the trainning process. We can change how we train by revising *train.py* can *config.py*

# %%
# !python3 YOLOv3/train.py
